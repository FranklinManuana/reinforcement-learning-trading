# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf

'''Will import agent model gym from gymnasium once environment setup understood'''

# %%
# retrieve ticker information corresponding to option of interest
msft = yf.Ticker('MSFT')

# %%
# view ticker data structure
msft.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
# retrive entire history of option
history = msft.history(period="max")

# %%
# 
history
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1986-03-13 00:00:00-05:00    0.054277    0.062259    0.054277    0.059598
# 1986-03-14 00:00:00-05:00    0.059598    0.062791    0.059598    0.061726
# 1986-03-17 00:00:00-05:00    0.061726    0.063323    0.061726    0.062791
# 1986-03-18 00:00:00-05:00    0.062791    0.063323    0.060662    0.061194
# 1986-03-19 00:00:00-05:00    0.061194    0.061726    0.059598    0.060130
# ...                               ...         ...         ...         ...
# 2025-06-04 00:00:00-04:00  464.000000  465.690002  463.019989  463.869995
# 2025-06-05 00:00:00-04:00  464.959991  469.649994  464.029999  467.679993
# 2025-06-06 00:00:00-04:00  470.089996  473.339996  468.779999  470.380005
# 2025-06-09 00:00:00-04:00  469.700012  473.429993  468.619995  472.750000
# 2025-06-10 00:00:00-04:00  471.184998  472.799988  466.959991  470.920013
#
#                                Volume  Dividends  Stock Splits
# Date
# ...

# %%
msft.actions # dividends, or splits
# Out:
#                            Dividends  Stock Splits
# Date
# 1987-09-21 00:00:00-04:00       0.00           2.0
# 1990-04-16 00:00:00-04:00       0.00           2.0
# 1991-06-27 00:00:00-04:00       0.00           1.5
# 1992-06-15 00:00:00-04:00       0.00           1.5
# 1994-05-23 00:00:00-04:00       0.00           2.0
# ...                              ...           ...
# 2024-05-15 00:00:00-04:00       0.75           0.0
# 2024-08-15 00:00:00-04:00       0.75           0.0
# 2024-11-21 00:00:00-05:00       0.83           0.0
# 2025-02-20 00:00:00-05:00       0.83           0.0
# 2025-05-15 00:00:00-04:00       0.83           0.0
#
# [95 rows x 2 columns]

# %%
msft.dividends
# Out:
# Date
# 2003-02-19 00:00:00-05:00    0.08
# 2003-10-15 00:00:00-04:00    0.16
# 2004-08-23 00:00:00-04:00    0.08
# 2004-11-15 00:00:00-05:00    3.08
# 2005-02-15 00:00:00-05:00    0.08
#                              ...
# 2024-05-15 00:00:00-04:00    0.75
# 2024-08-15 00:00:00-04:00    0.75
# 2024-11-21 00:00:00-05:00    0.83
# 2025-02-20 00:00:00-05:00    0.83
# 2025-05-15 00:00:00-04:00    0.83
# Name: Dividends, Length: 86, dtype: float64

# %%
msft.splits
# Out:
# Date
# 1987-09-21 00:00:00-04:00    2.0
# 1990-04-16 00:00:00-04:00    2.0
# 1991-06-27 00:00:00-04:00    1.5
# 1992-06-15 00:00:00-04:00    1.5
# 1994-05-23 00:00:00-04:00    2.0
# 1996-12-09 00:00:00-05:00    2.0
# 1998-02-23 00:00:00-05:00    2.0
# 1999-03-29 00:00:00-05:00    2.0
# 2003-02-18 00:00:00-05:00    2.0
# Name: Stock Splits, dtype: float64

# %%
msft.major_holders
# Out:
# Breakdown                          Value
# insidersPercentHeld              0.00063
# institutionsPercentHeld          0.74700
# institutionsFloatPercentHeld     0.74747
# institutionsCount             7511.00000

# %%
msft.institutional_holders
# Out:
#   Date Reported                         Holder  pctHeld     Shares  \
# 0    2025-03-31             Vanguard Group Inc   0.0930  691386214
# 1    2025-03-31                 Blackrock Inc.   0.0785  583284931
# 2    2025-03-31       State Street Corporation   0.0398  296030244
# 3    2025-03-31                       FMR, LLC   0.0262  194591253
# 4    2025-03-31  Geode Capital Management, LLC   0.0236  175469697
# 5    2025-03-31            JPMORGAN CHASE & CO   0.0191  142009968
# 6    2025-03-31  Price (T.Rowe) Associates Inc   0.0177  131514660
# 7    2025-03-31                 Morgan Stanley   0.0167  123846555
# 8    2024-12-31                    NORGES BANK   0.0142  105202984
# 9    2025-03-31     Northern Trust Corporation   0.0111   82539834
#
#           Value  pctChange
# 0  325587605180     0.0107
# 1  274680547538     0.0122
# 2  139406566479     0.0031
# 3   91636915475    -0.0148
# 4   82632192067     0.0437
# 5   66875336037     0.0524
# 6   61932885453    -0.0269
# ...

# %%
msft.cash_flow
# Out:
#                                                     2024-06-30     2023-06-30  \
# Free Cash Flow                                   74071000000.0  59475000000.0
# Repurchase Of Capital Stock                     -17254000000.0 -22245000000.0
# Repayment Of Debt                               -29070000000.0  -2750000000.0
# Issuance Of Debt                                 29645000000.0            0.0
# Issuance Of Capital Stock                         2002000000.0   1866000000.0
# Capital Expenditure                             -44477000000.0 -28107000000.0
# End Cash Position                                18315000000.0  34704000000.0
# Beginning Cash Position                          34704000000.0  13931000000.0
# Effect Of Exchange Rate Changes                   -210000000.0   -194000000.0
# Changes In Cash                                 -16179000000.0  20967000000.0
# Financing Cash Flow                             -37757000000.0 -43935000000.0
# ...

# %%
msft.recommendations_summary
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m         14   41     6     0           0
# 1    -1m         15   41     5     0           0
# 2    -2m         14   41     6     0           0
# 3    -3m         15   41     6     0           0

# %% [markdown]
# # Indices

# %% [markdown]
# ### View S&P 500 data

# %%
'''note ticker != stock symbol'''
sp500 = yf.Ticker("^GSPC")

# %%
sp500.info
# Out:
# {'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 6005.88,
#  'open': 6009.91,
#  'dayLow': 6000.28,
#  'dayHigh': 6043.01,
#  'regularMarketPreviousClose': 6005.88,
#  'regularMarketOpen': 6009.91,
#  'regularMarketDayLow': 6000.28,
#  'regularMarketDayHigh': 6043.01,
#  'volume': 2976909000,
#  'regularMarketVolume': 2976909000,
#  'averageVolume': 5239179047,
#  'averageVolume10days': 4969561000,
#  'averageDailyVolume10Day': 4969561000,
#  'bid': 5979.1,
#  'ask': 6070.37,
#  'bidSize': 0,
#  'askSize': 0,
#  'fiftyTwoWeekLow': 4835.04,
#  'fiftyTwoWeekHigh': 6147.43,
#  'fiftyDayAverage': 5636.0835,
#  'twoHundredDayAverage': 5798.3887,
#  'currency': 'USD',
#  'tradeable': False,
#  '52WeekChange': 11.730647,
#  'quoteType': 'INDEX',
#  'symbol': '^GSPC',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Index',
#  'quoteSourceName': 'Delayed Quote',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'shortName': 'S&P 500',
# ...

# %%
history_SP = sp500.history(period="max")
history_SP
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-06-04 00:00:00-04:00  5978.939941  5990.479980  5966.109863  5970.810059
# 2025-06-05 00:00:00-04:00  5985.669922  5999.700195  5921.200195  5939.299805
# 2025-06-06 00:00:00-04:00  5987.060059  6016.870117  5978.629883  6000.359863
# 2025-06-09 00:00:00-04:00  6004.629883  6021.310059  5994.180176  6005.879883
# 2025-06-10 00:00:00-04:00  6009.910156  6043.009766  6000.279785  6038.810059
#
# ...

# %% [markdown]
# ### View Nikkei225 data

# %%
nikkei = yf.Ticker("^N225")

# %%
nikkei
# Out:
# yfinance.Ticker object <^N225>

# %%
nikkei.info
# Out:
# {'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 38211.51,
#  'open': 38431.1,
#  'dayLow': 38398.23,
#  'dayHigh': 38529.64,
#  'regularMarketPreviousClose': 38211.51,
#  'regularMarketOpen': 38431.1,
#  'regularMarketDayLow': 38398.23,
#  'regularMarketDayHigh': 38529.64,
#  'volume': 0,
#  'regularMarketVolume': 0,
#  'averageVolume': 137201639,
#  'averageVolume10days': 116950000,
#  'averageDailyVolume10Day': 116950000,
#  'bid': 0.0,
#  'ask': 0.0,
#  'bidSize': 0,
#  'askSize': 0,
#  'fiftyTwoWeekLow': 30792.74,
#  'fiftyTwoWeekHigh': 42426.77,
#  'fiftyDayAverage': 36151.973,
#  'twoHundredDayAverage': 37889.855,
#  'currency': 'JPY',
#  'tradeable': False,
#  '52WeekChange': -2.6733756,
#  'quoteType': 'INDEX',
#  'symbol': '^N225',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Index',
#  'quoteSourceName': 'Delayed Quote',
#  'triggerable': False,
#  'customPriceAlertConfidence': 'LOW',
#  'shortName': 'Nikkei 225',
#  'longName': 'Nikkei 225',
# ...

# %%
history_japan = nikkei.history(period="max")

# %%
history_japan
# Out:
#                                    Open          High           Low  \
# Date
# 1965-01-05 00:00:00+09:00   1257.719971   1257.719971   1257.719971
# 1965-01-06 00:00:00+09:00   1263.989990   1263.989990   1263.989990
# 1965-01-07 00:00:00+09:00   1274.270020   1274.270020   1274.270020
# 1965-01-08 00:00:00+09:00   1286.430054   1286.430054   1286.430054
# 1965-01-12 00:00:00+09:00   1288.540039   1288.540039   1288.540039
# ...                                 ...           ...           ...
# 2025-06-04 00:00:00+09:00  37686.660156  37868.421875  37672.468750
# 2025-06-05 00:00:00+09:00  37590.390625  37732.878906  37527.878906
# 2025-06-06 00:00:00+09:00  37590.441406  37756.148438  37590.421875
# 2025-06-09 00:00:00+09:00  38028.710938  38178.011719  38018.218750
# 2025-06-11 00:00:00+09:00  38431.101562  38529.640625  38398.230469
#
#                                   Close     Volume  Dividends  Stock Splits
# Date
# ...

# %%
history_japan.head()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1965-01-05 00:00:00+09:00  1257.719971  1257.719971  1257.719971  1257.719971
# 1965-01-06 00:00:00+09:00  1263.989990  1263.989990  1263.989990  1263.989990
# 1965-01-07 00:00:00+09:00  1274.270020  1274.270020  1274.270020  1274.270020
# 1965-01-08 00:00:00+09:00  1286.430054  1286.430054  1286.430054  1286.430054
# 1965-01-12 00:00:00+09:00  1288.540039  1288.540039  1288.540039  1288.540039
#
#                            Volume  Dividends  Stock Splits
# Date
# 1965-01-05 00:00:00+09:00       0        0.0           0.0
# 1965-01-06 00:00:00+09:00       0        0.0           0.0
# 1965-01-07 00:00:00+09:00       0        0.0           0.0
# 1965-01-08 00:00:00+09:00       0        0.0           0.0
# 1965-01-12 00:00:00+09:00       0        0.0           0.0
